# %%
import requests, os, bs4
import lxml

# %%
url = 'https://icourse.club/course/20920/'
res = requests.get(url)
res.raise_for_status()

# %%
len(res.text)
# Out:
# 345406

# %%
exampleFile = open('comments.html','wb')
for chunk in res.iter_content(100000):
    exampleFile.write(chunk)
exampleFile.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/royalty/Desktop/Python_ML/Python-DL/Web-Python/web-try.ipynb 单元格 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/royalty/Desktop/Python_ML/Python-DL/Web-Python/web-try.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> exampleFile = open('comments.html','wb')
# ----> <a href='vscode-notebook-cell:/Users/royalty/Desktop/Python_ML/Python-DL/Web-Python/web-try.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> for chunk in res.iter_content(100000):
#       <a href='vscode-notebook-cell:/Users/royalty/Desktop/Python_ML/Python-DL/Web-Python/web-try.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a>     exampleFile.write(chunk)
#       <a href='vscode-notebook-cell:/Users/royalty/Desktop/Python_ML/Python-DL/Web-Python/web-try.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> exampleFile.close()
#
# NameError: name 'res' is not defined

# %%
print(exampleSoup.prettify())

# %%
yanhuijian = open('yanhuijian.html')
comments = bs4.BeautifulSoup(yanhuijian)

# %%
my = comments.select('p')

# %%
print(my)
# Out:
# [<p class="mobile"></p>, <p class="mobile"></p>, <p></p>, <p>给分溢出了，是怎么回事呢</p>, <p> </p>, <p>以下是一些<strong>“大问题”</strong>，请选择一定的立场，并为这一立场做辩护：</p>, <p> </p>, <p> </p>, <p>       <strong>“物质是运动的” -&gt; “运动是有规律的” -&gt; “规律是可以被把握的” -&gt; “因为人有意识” -&gt; “且意识具有主观能动性” -&gt; “但意识终究离不开物质及其运动规律” -&gt; “因此物质决定意识” 算不算有逻辑？</strong></p>, <p>       <strong>怎样从逻辑上推出资本主义金融危机和“两个必然”的？</strong></p>, <p>       这个过程和自然科学通过设定一系列假设（比如欧几里得五条公设，或量子物理的波函数假设），然后推出后面的东西有一定的相似之处——毕竟经典力学的开山之作也叫《自然哲学的数学原理》。这样一来也不难理解哲学有各种派别的争论，因为他们的基本假设不一样。数学家将第五公设稍作更改，创立的 Riemann 几何在欧氏几何看来有一系列的矛盾，也是如此。至于量子物理，它不符合人们的直觉，但并不代表着它的逻辑不顺畅。</p>, <p>       马克思理论的基本假设，是商品理论和劳动价值论。作为对比，新自由主义和凯恩斯主义这两个经济理论的基本假设就不同，反倒和物理上的统计力学非常相似，也搞 Boltzmann 分布（但马克思主义暂时还没有找到一个能够类比的物理模型）。剩下的大多是逻辑推导。比如像下面这样：</p>, <p><strong>       <em>定义：称一个理论是好理论（good_theory），当且仅当它逻辑自洽，能够帮助我们理解世界的运行机理，能够预测即将发生的情况。</em></strong></p>, <p><strong>       <em>定理一：好理论的“好度”（goodity）是它自洽程度、预测精度的一个度量，它是时间的单调函数：<span class="math-tex">\(\text{goodity}(t)\)</span></em></strong></p>, <p>    
# ...

# %%
newfile = open('mycommets','wb')
for chunk in my_iter_content:
# Out:
# <p class="mobile"></p>

# %%
print(comments.get_text())
# Out:
# 马克思主义基本原理（颜惠箭） - USTC评课社区
#
#
#
#
#
#
#
#
#
#
#
#
# 登录
# USTC评课社区
#
#
#
#
# 点评
# 课程
# 导师
#
#
#
#
#
#
#
#
#
#
# 登录
#
#
#
#
#
#
#
#
#
#
# 请登录
# 注册
#
#
# 用户名
#
# 密码
#
#
#
# 记住我
#
# 忘记密码
#
# 登录
#
#
#
#
#
#
#
#
#
#
#
#
#
# 马克思主义基本原理（颜惠箭）
# 2022秋 2021秋  课程号：MARX100319
# 2022秋 2021秋  课程号：MARX100319
#
#
#
#
#
# 		      所属培养方案
#
#
#
#
# 少年班学院
#
#
# 少年班数学平台专业培养方案
#
# 2020级 政治通修 2秋
# 2019级 政治通修 2秋
# 2018级 政治通修 2秋
# 2017级 政治通修 1春
# 2016级 政治通修 1春
# 2015级 政治通修 1春
#
#
#
# 少年班电子信息平台专业培养方案
#
# 2020级 政治通修 2秋
# 2019级 政治通修 2秋
# 2018级 政治通修 2秋
# 2017级 政治通修 1春
# 2016级 政治通修 1春
# 2015级 政治通修 1春
#
#
#
# 少年班学院培养方案（数学与应用数学）
#
# 2021级 政治通修 2秋
#
#
#
# 少年班学院培养方案（信息与计算科学）
#
# 2021级 政治通修 2秋
#
#
#
# 少年班学院培养方案（物理学）
#
# 2021级 政治通修 2秋
#
#
#
# 少年班学院培养方案（化学与材料）
#
# 2021级 政治通修 2秋
#
#
#
# 少年班学院培养方案（地球物理学）
#
# 2021级 政治通修 2秋
#
#
#
# 少年班学院培养方案（大气科学）
#
# 2021级 政治通修 2秋
#
#
#
# 少年班学院培养方案（机械设计制造及其自动化）
#
# 2021级 政治通修 2秋
#
#
#
# 少年班学院培养方案（通信工程）
#
# 2021级 政治通修 2秋
#
#
#
# 少年班学院培养方案（网络与新媒体）
#
# 2021级 政治通修 2秋
#
#
#
# ...

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soup = bs4.BeautifulSoup(html_doc,'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
print(soup.select('#link2'))
# Out:
# [<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>]
